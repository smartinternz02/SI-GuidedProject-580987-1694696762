# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(data = np.random.rand(4, 4), columns = ['Feature1', 'Feature2', 'Feature3', 'Feature4'])
df
# Out:
#    Feature1  Feature2  Feature3  Feature4
# 0  0.644097  0.182240  0.122645  0.699893
# 1  0.299860  0.014992  0.160089  0.591361
# 2  0.743122  0.240143  0.622132  0.001495
# 3  0.331849  0.345947  0.544414  0.353602

# %%
new_col = new_column_names = {
    'Feature1': 'Random value 1',
    'Feature2': 'Random value 2',
    'Feature3': 'Random value 3',
    'Feature4': 'Random value 4'
}
df = df.rename(columns=new_col)
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.644097        0.182240        0.122645        0.699893
# 1        0.299860        0.014992        0.160089        0.591361
# 2        0.743122        0.240143        0.622132        0.001495
# 3        0.331849        0.345947        0.544414        0.353602

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.504732        0.195831        0.362320        0.411588
# std          0.222196        0.138306        0.257554        0.309288
# min          0.299860        0.014992        0.122645        0.001495
# 25%          0.323852        0.140428        0.150728        0.265575
# 50%          0.487973        0.211192        0.352251        0.472481
# 75%          0.668853        0.266594        0.563844        0.618494
# max          0.743122        0.345947        0.622132        0.699893

# %%
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
df.loc[:, ['Random value 2', 'Random value 3']]
# Out:
#    Random value 2  Random value 3
# 0        0.182240        0.122645
# 1        0.014992        0.160089
# 2        0.240143        0.622132
# 3        0.345947        0.544414

# %%
df.iloc[:, [1, 2]]
# Out:
#    Random value 2  Random value 3
# 0        0.182240        0.122645
# 1        0.014992        0.160089
# 2        0.240143        0.622132
# 3        0.345947        0.544414
